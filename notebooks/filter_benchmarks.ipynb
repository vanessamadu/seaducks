# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Time tracking:
#
# |Percentage of data|Time to run|
# |---|---|
# |0.001%|31.93s|
# |0.005%|36.69s|
# |0.01%|40.50s|
# |0.05%|75.84s|
# |0.1%|126.37s|
# |0.5%|498.01s |
# |0.75%|793.66s|
# |1.0%|939.65s|
# |2.5%|1037.01s|
# |5.0%|4151.96s|

# %%
x = [0.001,0.005,0.01,0.05,0.1,0.5,0.75,1,2.5,5.0,7.5]
y = [31.93,36.69,40.50,75.84,126.37,498.01,793.66,939.65,1037.01,4151.96,]
plt.scatter(x,y)
plt.show()
