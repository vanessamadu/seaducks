# %%
import pickle

# %%
with open('error_metric_values.p', 'rb') as filehandler:
    err_metric_values = pickle.load(filehandler)

# %%
err_metric_values.drop(err_metric_values.index[[3*jj+1 for jj in range(5)]])
# Out:
#                     SST: True | Polar: False SST: False | Polar: False  \
# RMSE                            14.54 ± 0.05              14.78 ± 0.05
# RMSE 95 percent ci            (14.45, 14.63)            (14.69, 14.88)
# MAE                              9.84 ± 0.03               9.96 ± 0.03
# MAE 95 percent ci                (9.78, 9.9)              (9.9, 10.02)
# MAAO                            40.08 ± 0.07              40.49 ± 0.07
# MAAO 95 percent ci            (39.94, 40.22)            (40.34, 40.63)
# MAPE                           439.77 ± 8.83             442.71 ± 9.03
# MAPE 95 percent ci          (422.25, 457.29)           (424.8, 460.63)
# RMSLE                            0.22 ± 0.00               0.23 ± 0.00
# RMSLE 95 percent ci             (0.22, 0.22)              (0.22, 0.23)
#
#                     SST: True | Polar: True SST: False | Polar: True
# RMSE                           14.53 ± 0.05             14.75 ± 0.05
# ...

# %%
with open('goodness_of_fit_metric_values.p', 'rb') as filehandler:
    goodness_of_fit_values = pickle.load(filehandler)

# %%
goodness_of_fit_values.drop(goodness_of_fit_values.index[[2*jj+1 for jj in range(3)]])
# Out:
#             SST: True | Polar: False SST: False | Polar: False  \
# NLL                     -1.46 ± 0.01              -1.44 ± 0.01
# PR area                    2252 ± 11                 2396 ± 13
# PR coverage              0.86 ± 0.00               0.86 ± 0.00
#
#             SST: True | Polar: True SST: False | Polar: True
# NLL                    -1.46 ± 0.01             -1.43 ± 0.01
# PR area                   2262 ± 12                2390 ± 13
# PR coverage             0.86 ± 0.00              0.86 ± 0.00

# %%
names = ['SST: True | Polar: False','SST: False | Polar: False','SST: True | Polar: True','SST: False | Polar: True']
with open('model_0_feature_importances_values.p', 'rb') as filehandler:
    model_0_fi = pickle.load(filehandler)

# %%
model_0_fi = model_0_fi.style.set_caption(f"{names[0]}")
model_0_fi
# Out:
# <style type="text/css">
# </style>
# <table id="T_c275a">
#   <caption>SST: True | Polar: False</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c275a_level0_col0" class="col_heading level0 col0" >mu_x</th>
#       <th id="T_c275a_level0_col1" class="col_heading level0 col1" >mu_y</th>
#       <th id="T_c275a_level0_col2" class="col_heading level0 col2" >a_11</th>
#       <th id="T_c275a_level0_col3" class="col_heading level0 col3" >a_12</th>
#       <th id="T_c275a_level0_col4" class="col_heading level0 col4" >a_22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c275a_level0_row0" class="row_heading level0 row0" >u_av</th>
#       <td id="T_c275a_row0_col0" class="data row0 col0" >0.11</td>
#       <td id="T_c275a_row0_col1" class="data row0 col1" >0.07</td>
#       <td id="T_c275a_row0_col2" class="data row0 col2" >0.10</td>
#       <td id="T_c275a_row0_col3" class="data row0 col3" >0.09</td>
# ...

# %%
with open('model_1_feature_importances_values.p', 'rb') as filehandler:
    model_1_fi = pickle.load(filehandler)
model_1_fi = model_1_fi.style.set_caption(f"{names[1]}")
model_1_fi
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8ae7">
#   <caption>SST: False | Polar: False</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8ae7_level0_col0" class="col_heading level0 col0" >mu_x</th>
#       <th id="T_e8ae7_level0_col1" class="col_heading level0 col1" >mu_y</th>
#       <th id="T_e8ae7_level0_col2" class="col_heading level0 col2" >a_11</th>
#       <th id="T_e8ae7_level0_col3" class="col_heading level0 col3" >a_12</th>
#       <th id="T_e8ae7_level0_col4" class="col_heading level0 col4" >a_22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8ae7_level0_row0" class="row_heading level0 row0" >u_av</th>
#       <td id="T_e8ae7_row0_col0" class="data row0 col0" >0.12</td>
#       <td id="T_e8ae7_row0_col1" class="data row0 col1" >0.10</td>
#       <td id="T_e8ae7_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_e8ae7_row0_col3" class="data row0 col3" >0.10</td>
# ...

# %%
with open('model_2_feature_importances_values.p', 'rb') as filehandler:
    model_2_fi = pickle.load(filehandler)
model_2_fi = model_2_fi.style.set_caption(f"{names[2]}")
model_2_fi
# Out:
# <style type="text/css">
# </style>
# <table id="T_47f65">
#   <caption>SST: True | Polar: True</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47f65_level0_col0" class="col_heading level0 col0" >mu_x</th>
#       <th id="T_47f65_level0_col1" class="col_heading level0 col1" >mu_y</th>
#       <th id="T_47f65_level0_col2" class="col_heading level0 col2" >a_11</th>
#       <th id="T_47f65_level0_col3" class="col_heading level0 col3" >a_12</th>
#       <th id="T_47f65_level0_col4" class="col_heading level0 col4" >a_22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47f65_level0_row0" class="row_heading level0 row0" >u_av</th>
#       <td id="T_47f65_row0_col0" class="data row0 col0" >0.11</td>
#       <td id="T_47f65_row0_col1" class="data row0 col1" >0.13</td>
#       <td id="T_47f65_row0_col2" class="data row0 col2" >0.09</td>
#       <td id="T_47f65_row0_col3" class="data row0 col3" >0.12</td>
# ...

# %%
with open('model_3_feature_importances_values.p', 'rb') as filehandler:
    model_3_fi = pickle.load(filehandler)
model_3_fi = model_3_fi.style.set_caption(f"{names[3]}")
model_3_fi
# Out:
# <style type="text/css">
# </style>
# <table id="T_12b88">
#   <caption>SST: False | Polar: True</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12b88_level0_col0" class="col_heading level0 col0" >mu_x</th>
#       <th id="T_12b88_level0_col1" class="col_heading level0 col1" >mu_y</th>
#       <th id="T_12b88_level0_col2" class="col_heading level0 col2" >a_11</th>
#       <th id="T_12b88_level0_col3" class="col_heading level0 col3" >a_12</th>
#       <th id="T_12b88_level0_col4" class="col_heading level0 col4" >a_22</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12b88_level0_row0" class="row_heading level0 row0" >u_av</th>
#       <td id="T_12b88_row0_col0" class="data row0 col0" >0.12</td>
#       <td id="T_12b88_row0_col1" class="data row0 col1" >0.14</td>
#       <td id="T_12b88_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_12b88_row0_col3" class="data row0 col3" >0.13</td>
# ...
